# %%
# !pip install fastai kaggle -q

from fastai.vision.all import *
import torch
import os

os.environ["KAGGLE_USERNAME"] = "cooperg28"
os.environ["KAGGLE_KEY"] = 'XXX'
print("Kaggle configured")

print("PyTorch version:", torch.__version__)
print("GPU available:", torch.cuda.is_available())

# !kaggle datasets download -d jessicali9530/stanford-cars-dataset
# !unzip -q stanford-cars-dataset.zip -d cars_data
print("Dataset Downloaded")
# Out:
# Kaggle configured
# PyTorch version: 2.10.0+cu128
# GPU available: True
# 403 Client Error: Forbidden for url: https://api.kaggle.com/v1/datasets.DatasetApiService/GetDatasetMetadata
# unzip:  cannot find or open stanford-cars-dataset.zip, stanford-cars-dataset.zip.zip or stanford-cars-dataset.zip.ZIP.
# Dataset Downloaded
