# %% [markdown]
# <a href="https://colab.research.google.com/github/cooperg28/Car-Model-Image-Classifier/blob/main/ML_Car_Image_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fastai kaggle -q

from fastai.vision.all import *
import torch

print("PyTorch version:", torch.__version__)
print("GPU available:", torch.cuda.is_available())
# Out:
# PyTorch version: 2.10.0+cu128
# GPU available: True
